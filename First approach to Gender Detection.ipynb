# %% [markdown]
# # First method for outlier detection implemented with Pandas

# %% [markdown]
# ## Preliminary upload

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
import random as rnd
import ast
import hdbscan
from sklearn.decomposition import PCA , KernelPCA
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans , DBSCAN
from mpl_toolkits.mplot3d import Axes3D
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler
from sklearn.manifold import TSNE

# %% [markdown]
# ### Global function set up

# %%
def invert_dol(d):
    return dict((v, k) for k in d for v in d[k])

# %% [markdown]
# ### Import Data

# %%
dataset=pd.read_csv("Projet critéo/Dataset/DataSet initial/criteo_graph_enriched.csv", encoding = "ISO-8859-1", sep=";")
google_class= pd.read_csv("Projet critéo/Dataset/DataSet initial/google_product_taxonomy2.csv",";",encoding = "ISO-8859-1")
google_class=google_class.set_index('uc_id')

# %%
google_class
# Out:
#                     uc_level_1                   uc_level_2  \
# uc_id
# 1       Animals & Pet Supplies                          NaN
# 3237    Animals & Pet Supplies                 Live Animals
# 2       Animals & Pet Supplies                 Pet Supplies
# 3       Animals & Pet Supplies                 Pet Supplies
# 7385    Animals & Pet Supplies                 Pet Supplies
# 499954  Animals & Pet Supplies                 Pet Supplies
# 7386    Animals & Pet Supplies                 Pet Supplies
# 4989    Animals & Pet Supplies                 Pet Supplies
# 4990    Animals & Pet Supplies                 Pet Supplies
# 7398    Animals & Pet Supplies                 Pet Supplies
# 4991    Animals & Pet Supplies                 Pet Supplies
# 4992    Animals & Pet Supplies                 Pet Supplies
# 4993    Animals & Pet Supplies                 Pet Supplies
# 4       Animals & Pet Supplies                 Pet Supplies
# 5082    Animals & Pet Supplies                 Pet Supplies
# 4433    Animals & Pet Supplies                 Pet Supplies
# 3367    Animals & Pet Supplies                 Pet Supplies
# 4997    Animals & Pet Supplies                 Pet Supplies
# 500059  Animals & Pet Supplies                 Pet Supplies
# 4999    Animals & Pet Supplies                 Pet Supplies
# 8069    Animals & Pet Supplies                 Pet Supplies
# 7142    Animals & Pet Supplies                 Pet Supplies
# 5000    Animals & Pet Supplies                 Pet Supplies
# 5001    Animals & Pet Supplies                 Pet Supplies
# 5002    Animals & Pet Supplies                 Pet Supplies
# 5       Animals & Pet Supplies                 Pet Supplies
# 5004    Animals & Pet Supplies                 Pet Supplies
# 4434    Animals & Pet Supplies                 Pet Supplies
# 7372    Animals & Pet Supplies                 Pet Supplies
# 499900  Animals & Pet Supplies                 Pet Supplies
# ...                        ...                          ...
# 3806          Vehicles & Parts  Vehicle Parts & Accessories
# 1125          Vehicles & Parts  Vehicle Parts & Accessories
# 3619          Vehicles & Parts  Vehicle Parts & Accessories
# 3232          Vehicles & Parts  Vehicle Parts & Accessories
# 3309          Vehicles & Parts  Vehicle Parts & Accessories
# 3400          Vehicles & Parts  Vehicle Parts & Accessories
# 3415          Vehicles & Parts  Vehicle Parts & Accessories
# 3968          Vehicles & Parts  Vehicle Parts & Accessories
# 3892          Vehicles & Parts  Vehicle Parts & Accessories
# 3648          Vehicles & Parts  Vehicle Parts & Accessories
# 6293          Vehicles & Parts  Vehicle Parts & Accessories
# 3995          Vehicles & Parts  Vehicle Parts & Accessories
# 3663    Watercraft Parts & Accessories          Watercraft Steering Parts
# 5614                               NaN                                NaN
# 3395                          Aircraft                                NaN
# 1267                    Motor Vehicles                                NaN
# 916                     Motor Vehicles                Cars, Trucks & Vans
# 3931                    Motor Vehicles                         Golf Carts
# 919                     Motor Vehicles             Motorcycles & Scooters
# 503031                  Motor Vehicles  Off-Road and All-Terrain Vehicles
# 3018                    Motor Vehicles  Off-Road and All-Terrain Vehicles
# 2528                    Motor Vehicles  Off-Road and All-Terrain Vehicles
# 920                     Motor Vehicles              Recreational Vehicles
# 3549                    Motor Vehicles                        Snowmobiles
# 3540                        Watercraft                                NaN
# 3095                        Watercraft                        Motor Boats
# 1130                        Watercraft                Personal Watercraft
# 3087                        Watercraft                          Sailboats
# 5644                        Watercraft                             Yachts
#
#                            uc_level_5 uc_level_6 uc_level_7  \
# uc_id
# 1                                 NaN        NaN        NaN
# 3237                              NaN        NaN        NaN
# 2                                 NaN        NaN        NaN
# 3                                 NaN        NaN        NaN
# 7385                              NaN        NaN        NaN
# 499954           Bird Cage Bird Baths        NaN        NaN
# 7386    Bird Cage Food & Water Dishes        NaN        NaN
# 4989                              NaN        NaN        NaN
# 4990                              NaN        NaN        NaN
# 7398                              NaN        NaN        NaN
# 4991                              NaN        NaN        NaN
# 4992                              NaN        NaN        NaN
# 4993                              NaN        NaN        NaN
# 4                                 NaN        NaN        NaN
# 5082                              NaN        NaN        NaN
# 4433                              NaN        NaN        NaN
# 3367                              NaN        NaN        NaN
# 4997                              NaN        NaN        NaN
# 500059                            NaN        NaN        NaN
# 4999                              NaN        NaN        NaN
# 8069                              NaN        NaN        NaN
# 7142                              NaN        NaN        NaN
# 5000                              NaN        NaN        NaN
# 5001                              NaN        NaN        NaN
# 5002                              NaN        NaN        NaN
# 5                                 NaN        NaN        NaN
# 5004                              NaN        NaN        NaN
# 4434                              NaN        NaN        NaN
# 7372                              NaN        NaN        NaN
# 499900                            NaN        NaN        NaN
# ...                               ...        ...        ...
# 3806            Watercraft Propellers        NaN        NaN
# 1125                              NaN        NaN        NaN
# 3619                              NaN        NaN        NaN
# 3232             Watercraft Manifolds        NaN        NaN
# 3309      Watercraft Mufflers & Parts        NaN        NaN
# 3400                              NaN        NaN        NaN
# 3415    Watercraft Fuel Lines & Parts        NaN        NaN
# 3968           Watercraft Fuel Meters        NaN        NaN
# 3892    Watercraft Fuel Pumps & Parts        NaN        NaN
# 3648    Watercraft Fuel Tanks & Parts        NaN        NaN
# 6293                              NaN        NaN        NaN
# 3995                              NaN        NaN        NaN
# 3308       Watercraft Steering Cables        NaN        NaN
# 3663       Watercraft Steering Wheels        NaN        NaN
# 5614                              NaN        NaN        NaN
# 3395                              NaN        NaN        NaN
# 1267                              NaN        NaN        NaN
# 916                               NaN        NaN        NaN
# 3931                              NaN        NaN        NaN
# 919                               NaN        NaN        NaN
# 503031                            NaN        NaN        NaN
# 3018                      ATVs & UTVs        NaN        NaN
# 2528          Go Karts & Dune Buggies        NaN        NaN
# 920                               NaN        NaN        NaN
# 3968    Vehicles & Parts_Vehicle Parts & Accessories
# 3892    Vehicles & Parts_Vehicle Parts & Accessories
# 3648    Vehicles & Parts_Vehicle Parts & Accessories
# 6293    Vehicles & Parts_Vehicle Parts & Accessories
# 3995    Vehicles & Parts_Vehicle Parts & Accessories
# 3308    Vehicles & Parts_Vehicle Parts & Accessories
# 3663    Vehicles & Parts_Vehicle Parts & Accessories
# 5614                       Vehicles & Parts_Vehicles
# 3395                       Vehicles & Parts_Vehicles
# 1267                       Vehicles & Parts_Vehicles
# 916                        Vehicles & Parts_Vehicles
# 3931                       Vehicles & Parts_Vehicles
# 919                        Vehicles & Parts_Vehicles
# 503031                     Vehicles & Parts_Vehicles
# 3018                       Vehicles & Parts_Vehicles
# 2528                       Vehicles & Parts_Vehicles
# 920                        Vehicles & Parts_Vehicles
# 3549                       Vehicles & Parts_Vehicles
# 3540                       Vehicles & Parts_Vehicles
# 3095                       Vehicles & Parts_Vehicles
# 1130                       Vehicles & Parts_Vehicles
# 3087                       Vehicles & Parts_Vehicles
# 5644                       Vehicles & Parts_Vehicles
#
# [5427 rows x 9 columns]

# %% [markdown]
# ## Data set pre-analysis

# %% [markdown]
# ### Statistics

# %%
n_xd_id = dataset.xd_id.nunique()
avg_produt_per_uid = dataset.groupby('user_id').nb_views.sum().mean()
avg_unique_produt_per_uid = dataset.groupby('user_id').product.count().mean() #245.21
print ("numbre of cross_device on the sample : ",n_xd_id)
print ("average product per user Id : ",avg_produt_per_uid)
print ("average unique product per user Id : ",avg_unique_produt_per_uid)
# Out:
# ('numbre of cross_device on the sample : ', 1000)
# ('average product per user Id : ', 336.52288815479)
# ('average unique product per user Id : ', 245.21189240207644)

# %%
xd_id_group = dataset.groupby('xd_id')['user_id'].nunique()
distribution_u_id_selon_xd_id = xd_id_group.describe()
xd_id_group.plot(title="device number per cross device")

# %%
product_group_per_views = dataset.groupby('product').nb_views.sum()
product_group_per_views.plot(title="number of view per product")

# %%
product_group_per_user_id = dataset.groupby('product').user_id.count()
product_group_per_user_id.plot(title="number of user who have seen each product")

# %% [markdown]
# ### Gender error detection

# %% [markdown]
# #### Extraction of product cell's content

# %%
def extract_product (dataset): 
    dataset_added=dataset
    df2 = pd.DataFrame(dataset_added['product'].str.split(',',-1,False).tolist())
    df2_0=pd.DataFrame(df2[0].str.split('"',-1,False).tolist())
    df2_3=pd.DataFrame(df2[3].str.split('"',-1,False).tolist())
    dataset_added['product_id'] = df2_0[1]
    dataset_added['product_gender']=df2[1]
    dataset_added['product_gender_proba'] = df2[2]
    dataset_added['product_Gid']=pd.to_numeric(df2_3[1],errors='coerce')
    return (dataset_added)
dset = extract_product (dataset)

# %% [markdown]
# #### Extract anormal gender

# %%
def set_uid_gender(dataset):
    dataset['ponderation'] = dataset['product_gender_proba'].multiply(dataset['nb_views'])
    #dataset['ponderation'] = dataset['product_gender_proba']
    dataset_genred = dataset.groupby('product_gender').ponderation.sum()
    dataset_genred = dataset_genred.map(lambda x: min(x / dataset.ponderation.sum(),1))
    return dataset_genred.to_dict()

def set_gender(dataset):
    uid_grouped = dataset.groupby('user_id')[['product_id', 'nb_views', 'product_gender', 'product_gender_proba']]
    user_id_mapped = {unique_user_id: '' for unique_user_id in dataset.user_id.unique()}
    for i, user_id in enumerate(user_id_mapped.keys()):
        working_uid = uid_grouped.get_group(user_id)
        user_id_mapped[user_id] = set_uid_gender(working_uid) 
    dataset['user_id_sex'] = dataset.user_id.map(user_id_mapped)
    return dataset
    print (user_id_mapped)

def set_gender_reference(dataset):
    xid_grouped = dataset.groupby('xd_id')
    xd_id_mapped = {unique_xd_id: '' for unique_xd_id in dataset.xd_id.unique()}
    for i, xdid in enumerate(xd_id_mapped):
        working_xid = xid_grouped.get_group(xdid).drop_duplicates(subset = 'user_id')
        xd_id_mapped[xdid] = genderize(working_xid)
    dataset['xd_id_sex_interval'] = dataset.xd_id.map(xd_id_mapped)
    return dataset
        
def genderize(working_xid):
    U, F, M = [], [], []
    for uid_gender in working_xid.user_id_sex:
        try:
            U.append(uid_gender['UNISEX'])
            F.append(uid_gender['FEMALE'])
            M.append(uid_gender['MALE'])
        except:
            pass
    return [validation_interval(F), validation_interval(M), validation_interval(U)]

def validation_interval(liste, seuil=2):
    try:
        answer = [max(0,statistics.mean(liste) - seuil * statistics.stdev(liste)), min(statistics.mean(liste) + seuil * statistics.stdev(liste),1)]
    except:
        answer = [0,1]
    return answer

def find_anomaly(working_uid):
    gender = working_uid.user_id_sex.values[0]
    for key, value in gender.items():
        if key == 'FEMALE':
            if value < working_uid.xd_id_sex_interval.values[0][0][0] or value > working_uid.xd_id_sex_interval.values[0][0][1]:
                return True
        elif key == 'MALE':
            if value < working_uid.xd_id_sex_interval.values[0][1][0] or value > working_uid.xd_id_sex_interval.values[0][1][1]:
                return True
        elif key == 'UNISEX':
            if value < working_uid.xd_id_sex_interval.values[0][2][0] or value > working_uid.xd_id_sex_interval.values[0][2][1]:
                return True
    return False
    
def set_anomaly(dataset):
    uid_grouped = dataset.groupby('user_id')
    user_id_mapped = {unique_user_id: '' for unique_user_id in dataset.user_id.unique()}
    progress = 0.1
    for i, user_id in enumerate(user_id_mapped.keys()):
        working_uid = uid_grouped.get_group(user_id).drop_duplicates(subset = 'user_id')
        anomaly = find_anomaly(working_uid)
        user_id_mapped[user_id] = anomaly
        dataset['anomaly'] = dataset.user_id.map(user_id_mapped)
    print('--> {} anomalies detected among xd_id ({}%)'.format(len(dataset[dataset.anomaly].xd_id.unique()), round((len(dataset[dataset.anomaly].xd_id.unique()) / len(dataset.xd_id.unique()))*100,2)))
    print('--> {} ud_id are missclassified ({}%)'.format(len(dataset[dataset.anomaly].user_id.unique()), round((len(dataset[dataset.anomaly].user_id.unique()) / len(dataset.user_id.unique()))*100,2)))
    return dataset

# %%
dataset_gender_detection = set_gender(dset)
dataset_gender_detection = set_gender_reference(dataset_gender_detection)
dataset_gender_detection = set_anomaly(dataset_gender_detection)
print "here is the abnormal user id : ",dataset_gender_detection[dataset.anomaly].xd_id.unique()
